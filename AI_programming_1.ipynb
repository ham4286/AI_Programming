# %% [markdown]
# <a href="https://colab.research.google.com/github/ham4286/AI_Programming/blob/main/AI_programming_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
# Out:
# hi

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.12.0

# %%
#환경 준비
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# %%
#데이터 준비
# !git clone http://github.com/taehojo/data.git

Data_set = np.loadtxt('./data/ThoraricSurgery3.csv', delimiter = ',')
X = Data_set[:,0:16]
y = Data_set[:, 16]
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.

# %%
#모델 구조 설계
model = Sequential()
model.add(Dense(30, input_dim = 16, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
#모델 실행
from IPython.core import history
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
history = model.fit(X, y, epochs = 5, batch_size = 16)
# Out:
# Epoch 1/5
# 30/30 [==============================] - 1s 3ms/step - loss: 3.0584 - accuracy: 0.3787
# Epoch 2/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6068 - accuracy: 0.8511
# Epoch 3/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4722 - accuracy: 0.8511
# Epoch 4/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4586 - accuracy: 0.8511
# Epoch 5/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4538 - accuracy: 0.8511

# %%
#최소 제곱
import numpy as np
x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])
mx = np.mean(x)
my = np.mean(y)
print('mean of x: {}, mean of y: {}'.format(mx, my))
down = sum([(i - mx)**2 for i in x]) #sum([a, b, c])

top = 0
for i in range(len(x)):
  top = top + (x[i] - mx) * (y[i] - my)
a = top / down
b = my - (mx * a)
print('regression line: y = {}x + {}'.format(a, b))
# Out:
# mean of x: 5.0, mean of y: 90.5
# regression line: y = 2.3x + 79.0

# %%
#임의의 직선을 긋고 MSE 계산
import numpy as np
x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])
a = 3
b = 76
y_pred = []
for i in range(len(x)):
  y_pred.append(a * x[i] + b)
def mse(y, y_pred):
  return (1/len(x)) * sum((y - y_pred)**2)
print('x:', x)
print('y:', y)
print('y_pred:', y_pred)
print('mse:', str(mse(y, y_pred)))
# Out:
# x: [2 4 6 8]
# y: [81 93 91 97]
# y_pred: [82, 88, 94, 100]
# mse: 11.0

# %%
#선형회귀
import numpy as np
import matplotlib.pyplot as plt
x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])
a = 0
b = 0
lr = 0.03  # learning rate
epochs = 2001 # epochs
n = len(x) # number of x
# gradient decent
for i in range(epochs):
   y_pred = a * x + b
   error = y - y_pred

   a_diff = (2/n) * sum(-x * error)
   b_diff = (2/n) * sum(-error)

   a = a - lr * a_diff
   b = b - lr * b_diff
   if(i % 100 == 0):
       print('epoch: {}, a: {}, b: {}'.format(i, a, b))

plt.scatter(x, y)
plt.plot(x, y_pred, 'r')
plt.show()
# Out:
# epoch: 0, a: 27.84, b: 5.43
# epoch: 100, a: 7.073858435872394, b: 50.51166161138297
# epoch: 200, a: 4.095999380762421, b: 68.28224379060177
# epoch: 300, a: 2.9756829100119027, b: 74.96781336233505
# epoch: 400, a: 2.5542024233262106, b: 77.48302865233052
# epoch: 500, a: 2.3956349066513707, b: 78.42929177728175
# epoch: 600, a: 2.3359793398132864, b: 78.78529068727728
# epoch: 700, a: 2.313535987420573, b: 78.91922301600925
# epoch: 800, a: 2.3050924490666174, b: 78.96961044185792
# epoch: 900, a: 2.3019158585694823, b: 78.98856697541248
# epoch: 1000, a: 2.3007207758016315, b: 78.99569871827002
# epoch: 1100, a: 2.300271167070735, b: 78.99838179089187
# epoch: 1200, a: 2.3001020172709508, b: 78.9993912045567
# epoch: 1300, a: 2.300038380484562, b: 78.99977096168232
# epoch: 1400, a: 2.3000144393354365, b: 78.9999138322214
# epoch: 1500, a: 2.3000054323026444, b: 78.99996758234106
# epoch: 1600, a: 2.300002043716771, b: 78.99998780397235
# ...

# %%
#다중 선형 회귀
import numpy as np
import matplotlib.pyplot as plt
x1 = np.array([2, 4, 6, 8])
x2 = np.array([0, 4, 2, 3])
y = np.array([81, 93, 91, 97])
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter3D(x1, x2, y)
plt.title("Scatter plot")
plt.show()
a1 = 0
a2 = 0
b = 0
lr = 0.005  # learning rate
epochs = 10001 # epochs
n = len(x1) # number of x

# gradient decent
for i in range(epochs):
  y_pred = a1 * x1 + a2 * x2 + b
  error = y - y_pred

  a1_diff = (2/n) * sum(-x1 * error)
  a2_diff = (2/n) * sum(-x2 * error)
  b_diff = (2/n) * sum(-error)

  a1 = a1 - lr * a1_diff
  a2 = a2 - lr * a2_diff
  b = b - lr * b_diff
  if(i % 1000 == 0):
     print('epoch: {}, a1: {}, a2: {}, b: {}'.format(i, a1, a2, b))
y_pred = a1 * x1 + a2 * x2 + b # regression with the last value of a and b.
print('y:', y)
print('y_pred:', y_pred)
# Out:
# epoch: 0, a1: 4.64, a2: 2.1125, b: 0.905
# epoch: 1000, a1: 3.7511410631947935, a2: 3.0629818794100716, b: 62.40081844921527
# epoch: 2000, a1: 1.9602077881516542, a2: 2.444613621806417, b: 74.69735799145944
# epoch: 3000, a1: 1.5940817211836333, a2: 2.3181985752448555, b: 77.21117812906293
# epoch: 4000, a1: 1.51923342126918, a2: 2.2923551508824715, b: 77.72508626226039
# epoch: 5000, a1: 1.5039319486193836, a2: 2.287071898604064, b: 77.83014611336745
# epoch: 6000, a1: 1.5008038205854808, a2: 2.2859918267743424, b: 77.85162382816048
# epoch: 7000, a1: 1.5001643275627907, a2: 2.285771024303466, b: 77.85601458474224
# epoch: 8000, a1: 1.5000335939989173, a2: 2.2857258849619777, b: 77.85691220087826
# epoch: 9000, a1: 1.5000068677265428, a2: 2.2857166569848646, b: 77.85709570335939
# epoch: 10000, a1: 1.500001403990876, a2: 2.285714770480565, b: 77.85713321734701
# y: [81 93 91 97]
# y_pred: [80.85713603 92.99999792 91.42857118 96.71428876]

# %%
#tensorflow에서 실행하는 선형회귀
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])

model = Sequential()
model.add(Dense(1, input_dim = 1, activation = 'linear'))

model.compile(optimizer = 'sgd', loss = 'mse')
model.fit(x,y, epochs = 2000)

y_pred = model.predict(x)

plt.scatter(x,y)
plt.plot(x, y_pred,'r')
plt.show()

#hours = int(input("Input hours as integer"))
hour = 7
exp_score = model.predict([hour])
print('The expected score is', exp_score)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 2s 2s/step - loss: 7118.9512
# Epoch 2/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 1882.2695
# Epoch 3/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 1107.7601
# Epoch 4/2000
# 1/1 [==============================] - 0s 24ms/step - loss: 988.6670
# Epoch 5/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 965.8728
# Epoch 6/2000
# 1/1 [==============================] - 0s 26ms/step - loss: 957.2571
# Epoch 7/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 950.7578
# Epoch 8/2000
# 1/1 [==============================] - 0s 26ms/step - loss: 944.6032
# Epoch 9/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 938.5331
# Epoch 10/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 932.5086
# Epoch 11/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 926.5242
# Epoch 12/2000
# ...

# %%
#tensorflow에서 실행하는 다중선형회귀
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([[2, 0], [4, 4], [6, 2], [8, 3]]) # input dimension: 2
y = np.array([81, 93, 91, 97])

model = Sequential()
model.add(Dense(1, input_dim = 2, activation = 'linear'))

model.compile(optimizer = 'sgd', loss = 'mse')
model.fit(x, y, epochs = 2000)

y_pred = model.predict(x)

#hours = int(input("Input hours as integer"))
hour = 7
tutor = 4
exp_score = model.predict([[hour, tutor]])
print('The expected score is', exp_score)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 1s 522ms/step - loss: 9041.0186
# Epoch 2/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 1493.5168
# Epoch 3/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 957.2324
# Epoch 4/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 914.0820
# Epoch 5/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 905.6498
# Epoch 6/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 899.6953
# Epoch 7/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 893.9509
# Epoch 8/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 888.2563
# Epoch 9/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 882.6007
# Epoch 10/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 876.9822
# Epoch 11/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 871.4009
# Epoch 12/2000
# ...

# %%
#tensorflow에서 실행하는 선형회귀
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([2, 4, 6, 8,10, 12, 14])
y = np.array([0, 0, 0, 1, 1, 1, 1])

model = Sequential()
model.add(Dense(1, input_dim = 1, activation = 'sigmoid'))

model.compile(optimizer = 'sgd', loss = 'binary_crossentropy')
model.fit(x,y, epochs = 5000)


plt.scatter(x,y)
plt.plot(x, model.predict(x),'r')
plt.show()

hours = 7
prediction = model.predict([hours])

print('{}시간 공부하면 합격 확률은 {}입니다.'.format(hours, prediction))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 1467/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3325
# Epoch 1468/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3324
# Epoch 1469/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3323
# Epoch 1470/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3322
# Epoch 1471/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3321
# Epoch 1472/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3320
# Epoch 1473/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3319
# Epoch 1474/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3318
# Epoch 1475/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3317
# Epoch 1476/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3316
# Epoch 1477/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3316
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# !git clone http://github.com/taehojo/data.git

Data_set = np.loadtxt('./data/ThoraricSurgery3.csv', delimiter = ',')
X = Data_set[:,0:16]
y = Data_set[:, 16]

model = Sequential()
model.add(Dense(30, input_dim = 16, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
history = model.fit(X, y, epochs = 5, batch_size=16)
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.
# Epoch 1/5
# 30/30 [==============================] - 1s 3ms/step - loss: 17.7466 - accuracy: 0.1489
# Epoch 2/5
# 30/30 [==============================] - 0s 3ms/step - loss: 7.4034 - accuracy: 0.1489
# Epoch 3/5
# 30/30 [==============================] - 0s 3ms/step - loss: 0.8254 - accuracy: 0.6532
# Epoch 4/5
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5395 - accuracy: 0.8319
# Epoch 5/5
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4705 - accuracy: 0.8468

# %%
#판다스
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/data/pima-indians-diabetes3.csv')
print(df.head(5))
print(df['diabetes'].value_counts()) #정상과 당뇨 환자 수
print(df.describe()) #각 항목에 대한 통계량
print(df.corr()) #상관관계
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    pregnant  plasma  pressure  thickness  insulin   bmi  pedigree  age  \
# 0         6     148        72         35        0  33.6     0.627   50
# 1         1      85        66         29        0  26.6     0.351   31
# 2         8     183        64          0        0  23.3     0.672   32
# 3         1      89        66         23       94  28.1     0.167   21
# 4         0     137        40         35      168  43.1     2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1
# 0    500
# 1    268
# Name: diabetes, dtype: int64
#          pregnant      plasma    pressure   thickness     insulin         bmi  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# ...

# %%
#상관관계 그래프
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/data/pima-indians-diabetes3.csv')
print(df.head(5))

#heatmap setting
colormap = plt.cm.gist_heat
plt.figure(figsize = (12, 12))

#heatmap plotting
sns.heatmap(df.corr(), linewidth = 0.5, vmax = 0.5, cmap = colormap, annot = True)
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    pregnant  plasma  pressure  thickness  insulin   bmi  pedigree  age  \
# 0         6     148        72         35        0  33.6     0.627   50
# 1         1      85        66         29        0  26.6     0.351   31
# 2         8     183        64          0        0  23.3     0.672   32
# 3         1      89        66         23       94  28.1     0.167   21
# 4         0     137        40         35      168  43.1     2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
#상관관계 히스토그램
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/data/pima-indians-diabetes3.csv')
print(df.head(5))

#plasma
plt.hist(x = [df.plasma[df.diabetes == 0], df.plasma[df.diabetes == 1]], bins=30,
         histtype = 'barstacked', label = ['normal', 'diabetes'])
#plt.hist(x = [df.plasma[df.diabetes == 0], df.plasma[df.diabetes == 1]], bins=10,
         #histtype = 'barstacked', label = ['normal', 'diabetes'])
plt.legend()
plt.show()

#bmi
plt.hist(x = [df.bmi[df.diabetes == 0], df.bmi[df.diabetes == 1]], bins=30,
         histtype = 'barstacked', label = ['normal', 'bmi'])

plt.legend()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    pregnant  plasma  pressure  thickness  insulin   bmi  pedigree  age  \
# 0         6     148        72         35        0  33.6     0.627   50
# 1         1      85        66         29        0  26.6     0.351   31
# 2         8     183        64          0        0  23.3     0.672   32
# 3         1      89        66         23       94  28.1     0.167   21
# 4         0     137        40         35      168  43.1     2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
# !pwd
# Out:
# /content

# %%
# !ls /content/data -la
# Out:
# total 1408
# drwxr-xr-x 5 root root   4096 Aug 12 02:03 .
# drwxr-xr-x 1 root root   4096 Aug 12 05:54 ..
# drwxr-xr-x 8 root root   4096 Aug 12 02:03 .git
# -rw-r--r-- 1 root root 451405 Aug 12 02:03 house_test.csv
# -rw-r--r-- 1 root root 460676 Aug 12 02:03 house_train.csv
# drwxr-xr-x 2 root root   4096 Aug 12 02:03 img
# -rw-r--r-- 1 root root   4466 Aug 12 02:03 iris3.csv
# drwxr-xr-x 2 root root   4096 Aug 12 02:03 model
# -rw-r--r-- 1 root root  23078 Aug 12 02:03 pima-indians-diabetes3.csv
# -rw-r--r-- 1 root root  85876 Aug 12 02:03 sonar3.csv
# -rw-r--r-- 1 root root  19015 Aug 12 02:03 ThoraricSurgery3.csv
# -rw-r--r-- 1 root root 361279 Aug 12 02:03 wine.csv

# %%
# !sum /content/data/pima-indians-diabetes3.csv
# Out:
# 03149    23

# %%
#당뇨병 예측
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

drive.mount('/content/drive')

#훈련 데이터
df = pd.read_csv('/content/data/pima-indians-diabetes3.csv')
X = df.iloc[:, 0:8] #0-7
y = df.iloc[:, 8] #8

#모델
model = Sequential()
model.add(Dense(12, input_dim = 8, activation = 'relu', name = 'Dense_1'))
model.add(Dense(8, activation = 'relu', name = 'Dense_2'))
model.add(Dense(1, activation = 'sigmoid', name = 'Dense_3'))

#모델 컴파일
model.summary()
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.fit(X, y, epochs = 100, batch_size = 10)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Dense_1 (Dense)             (None, 12)                108
#
#  Dense_2 (Dense)             (None, 8)                 104
#
#  Dense_3 (Dense)             (None, 1)                 9
#
# ...
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 77/77 [==============================] - 4s 8ms/step - loss: 7.3546 - accuracy: 0.4753
# Epoch 2/100
# 77/77 [==============================] - 0s 6ms/step - loss: 2.8217 - accuracy: 0.5508
# Epoch 3/100
# 77/77 [==============================] - 0s 6ms/step - loss: 1.6612 - accuracy: 0.5859
# Epoch 4/100
# ...

# %%
#아이리스 품종 분류_판다스
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/data/iris3.csv')
print(df.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#아이리스 품종 분류_상관도
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/data/iris3.csv')

sns.pairplot(df, hue = 'species')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#아이리스 품종 데이터프레임
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
df = pd.read_csv('/content/data/iris3.csv')
X = df.iloc[:, 0:4]
y = df.iloc[:, 4]
y = pd.get_dummies(y) #원-핫 인코딩(one-hot encoding) for y
print(X[0:5])
print(y[0:150])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0              1                0               0
# 1              1                0               0
# 2              1                0               0
# 3              1                0               0
# 4              1                0               0
# ..           ...              ...             ...
# 145            0                0               1
# 146            0                0               1
# 147            0                0               1
# ...

# %%
#다중분류
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(12, input_dim = 4, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(3, activation = 'softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.fit(X,y, epochs = 100, batch_size = 10)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 3ms/step - loss: 1.7397 - accuracy: 0.2533
# Epoch 2/100
# 15/15 [==============================] - 0s 3ms/step - loss: 1.4410 - accuracy: 0.0000e+00
# Epoch 3/100
# 15/15 [==============================] - 0s 4ms/step - loss: 1.2900 - accuracy: 0.0467
# Epoch 4/100
# 15/15 [==============================] - 0s 3ms/step - loss: 1.1741 - accuracy: 0.3267
# Epoch 5/100
# 15/15 [==============================] - 0s 3ms/step - loss: 1.0934 - accuracy: 0.3333
# Epoch 6/100
# 15/15 [==============================] - 0s 3ms/step - loss: 1.0406 - accuracy: 0.3333
# Epoch 7/100
# 15/15 [==============================] - 0s 3ms/step - loss: 1.0177 - accuracy: 0.3333
# Epoch 8/100
# 15/15 [==============================] - 0s 3ms/step - loss: 1.0082 - accuracy: 0.3600
# Epoch 9/100
# 15/15 [==============================] - 0s 4ms/step - loss: 1.0032 - accuracy: 0.5400
# Epoch 10/100
# ...
