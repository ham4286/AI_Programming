# %% [markdown]
# <a href="https://colab.research.google.com/github/ham4286/AI_Programming/blob/main/AI_programming_1(2024).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
data_set = np.loadtxt('/content/drive/MyDrive/Colab Notebooks/data/Digital_sprout_2023-20240217T004753Z-001/Digital_sprout_2023/데이터셋/ThoraricSurgery3.csv', delimiter = ',')
X = data_set[:, 0:16]
y = data_set[:, 16]

# %%
model = Sequential()
model.add(Dense(30, input_dim = 16, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
history = model.fit(X, y, epochs = 5, batch_size = 16)
# Out:
# Epoch 1/5
# 30/30 [==============================] - 1s 3ms/step - loss: 1.3950 - accuracy: 0.8404
# Epoch 2/5
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6380 - accuracy: 0.8277
# Epoch 3/5
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4569 - accuracy: 0.8404
# Epoch 4/5
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4352 - accuracy: 0.8511
# Epoch 5/5
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4308 - accuracy: 0.8511

# %%
#최소 제곱법
import numpy as np
x = np.array([1, 3, 5, 7, 9])
y = np.array([75, 77, 85, 83, 90])
mx = np.mean(x)
my = np.mean(y)

print('mean fo x: {}, mean of y : {}'.format(mx, my))

down = sum([(i - mx) ** 2 for i in x])

top = 0
for i in range(len(x)):
  top = top + (x[i] - mx) * (y[i] - my)
a = top / down
b = my - (mx * a)
print('regression line : y = {}x + {}'.format(a,b))
# Out:
# mean fo x: 5.0, mean of y : 82.0
# regression line : y = 1.8x + 73.0

# %%
#임의의 직선을 긋고 MSE 계산
import numpy as np
x = np.array([1, 3, 5, 7, 9])
y = np.array([75, 77, 85, 83, 90])

a = 2
b = 75

y_pred = []
for i in range(len(x)):
  y_pred.append(a * x[i] + b)

def mse(y, y_pred):
  return (1/len(x)) * sum((y - y_pred) ** 2)

print('x : ',x)
print('y : ',y)
print('y_pred : ', y_pred)
print('mse : ', str(mse(y, y_pred)))
# Out:
# x :  [1 3 5 7 9]
# y :  [75 77 85 83 90]
# y_pred :  [77, 81, 85, 89, 93]
# mse :  13.0

# %%
#선형회귀
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 3, 5, 7, 9])
y = np.array([75, 77, 85, 83, 90])

a = 0
b = 0
lr = 0.003 #learning rate
epochs = 8000
n = len(x)

for i in range(epochs):
  y_pred = a * x + b
  error = y - y_pred
  a_diff = (2/n) * sum(-x * error)
  b_diff = (2/n) * sum(-error)

  a = b - lr * a_diff
  b = b - lr * b_diff

  if(i & 100 == 0):
    print('epoch : {}, a : {}, b : {}'.format(i, a, b))
plt.scatter(x,y)
plt.plot(x, y_pred, 'r')
plt.show()
# Out:
# epoch : 0, a : 2.5464, b : 0.492
# epoch : 1, a : 2.5194528, b : 0.9046559999999999
# epoch : 2, a : 2.9250646656, b : 1.31564448
# epoch : 3, a : 3.243412341811201, b : 1.711998673152
# epoch : 8, a : 4.7466233600490035, b : 3.518635728094745
# epoch : 9, a : 5.0196452309622, b : 3.8471252129247064
# epoch : 10, a : 5.28422170080645, b : 4.165453104718292
# epoch : 11, a : 5.540613614817066, b : 4.473933735065789
# epoch : 16, a : 6.708398100204919, b : 5.878965881332741
# epoch : 17, a : 6.920734081052185, b : 6.134440143038597
# epoch : 18, a : 7.126501590699106, b : 6.382011479748799
# epoch : 19, a : 7.3259038203979125, b : 6.621924363149334
# epoch : 24, a : 8.234118194275858, b : 7.714652009735747
# epoch : 25, a : 8.399257046977056, b : 7.913340551849057
# epoch : 26, a : 8.559287439992127, b : 8.10588279712865
# epoch : 27, a : 8.71436740009635, b : 8.292468877146115
# epoch : 128, a : 13.369184482617067, b : 13.892960855878748
# ...

# %%
#ekwnd선형회귀
import numpy as np
import matplotlib.pyplot as plt

x1 = np.array([1, 3, 5, 7, 9])
x2 = np.array([0, 1, 5, 2, 4])
y = np.array([75, 77, 85, 83, 90])

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.scatter3D(x1, x2, y)
plt.title("Scatter plot")
plt.show()

a1 = 0
a2 = 0
b = 0
lr = 0.003 #learning rate
epochs = 20001
n = len(x)

for i in range(epochs):
  y_pred = a1 * x1 + a2 * x2 + b
  error = y - y_pred
  a_diff = (2/n) * sum(-x * error)
  b_diff = (2/n) * sum(-error)

  a = b - lr * a_diff
  b = b - lr * b_diff

  if(i & 100 == 0):
    print('epoch : {}, a1 : {}, a2 : {}, b : {}'.format(i, a1, a2, b))
y_pred = a1 * x1 + a2 * x2 + b
print('y : ', y)
print('y_pred : ', y_pred)
# Out:
# epoch : 0, a1 : 0, a2 : 0, b : 0.492
# epoch : 1, a1 : 0, a2 : 0, b : 0.9810479999999999
# epoch : 2, a1 : 0, a2 : 0, b : 1.467161712
# epoch : 3, a1 : 0, a2 : 0, b : 1.950358741728
# epoch : 8, a1 : 0, a2 : 0, b : 4.323202497749091
# epoch : 9, a1 : 0, a2 : 0, b : 4.7892632827625965
# epoch : 10, a1 : 0, a2 : 0, b : 5.252527703066021
# epoch : 11, a1 : 0, a2 : 0, b : 5.713012536847625
# epoch : 16, a1 : 0, a2 : 0, b : 7.974323131401911
# epoch : 17, a1 : 0, a2 : 0, b : 8.4184771926135
# epoch : 18, a1 : 0, a2 : 0, b : 8.85996632945782
# epoch : 19, a1 : 0, a2 : 0, b : 9.298806531481072
# epoch : 24, a1 : 0, a2 : 0, b : 11.453826469927455
# epoch : 25, a1 : 0, a2 : 0, b : 11.87710351110789
# epoch : 26, a1 : 0, a2 : 0, b : 12.297840890041243
# epoch : 27, a1 : 0, a2 : 0, b : 12.716053844700996
# epoch : 128, a1 : 0, a2 : 0, b : 44.272551092203834
# epoch : 129, a1 : 0, a2 : 0, b : 44.49891578565061
# epoch : 130, a1 : 0, a2 : 0, b : 44.723922290936706
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([1, 3, 5, 7, 9])
y = np.array([75, 77, 85, 83, 90])

model = Sequential()
model.add(Dense(1, input_dim = 1, activation = 'linear'))
model.compile(optimizer='sgd', loss = 'mse')
model.fit(x, y, epochs = 2000)

y_pred = model.predict(x)

plt.scatter(x, y)
plt.plot(x, y_pred, 'r')
plt.show()

hours = 7
exp_score = model.predict([hours])
print('The expected score is ', exp_score)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 407ms/step - loss: 6435.4028
# Epoch 2/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 1767.6176
# Epoch 3/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 1265.1089
# Epoch 4/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 1201.9481
# Epoch 5/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1185.2153
# Epoch 6/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1173.4738
# Epoch 7/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1162.3527
# Epoch 8/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 1151.3907
# Epoch 9/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 1140.5381
# Epoch 10/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1129.7888
# Epoch 11/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 1119.1409
# Epoch 12/2000
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([[1, 0], [3, 1], [5, 5], [7, 2], [9, 4]])
y = np.array([75, 77, 85, 83, 90])

model = Sequential()
model.add(Dense(1, input_dim = 2, activation = 'linear'))
model.compile(optimizer='sgd', loss = 'mse')
model.fit(x, y, epochs = 2000)


hours = 6
genealogy = 4
exp_score = model.predict([[hours, genealogy]])
print('The expected score is', exp_score)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 287ms/step - loss: 7662.0796
# Epoch 2/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 1416.7069
# Epoch 3/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1222.8916
# Epoch 4/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1204.9623
# Epoch 5/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1192.3228
# Epoch 6/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 1180.0143
# Epoch 7/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1167.8875
# Epoch 8/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1155.9332
# Epoch 9/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 1144.1461
# Epoch 10/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1132.5214
# Epoch 11/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 1121.0549
# Epoch 12/2000
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([1, 3, 5, 7, 9, 11, 13])
y = np.array([0, 0, 0, 1, 1, 1, 1])

model = Sequential()
model.add(Dense(1, input_dim = 1, activation = 'sigmoid'))
model.compile(optimizer='sgd', loss = 'binary_crossentropy')
model.fit(x, y, epochs = 1000)

y_pred = model.predict(x)

plt.scatter(x, y)
plt.plot(x, model.predict(x), 'r')
plt.show()

hours = 6
exp_score = model.predict([hours])
print('{}시간 공부하면 합격 확률은 {}입니다.'.format(hours, exp_score))
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 2s 2s/step - loss: 1.5374
# Epoch 2/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3130
# Epoch 3/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1201
# Epoch 4/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.9630
# Epoch 5/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8423
# Epoch 6/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.7541
# Epoch 7/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6915
# Epoch 8/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6476
# Epoch 9/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6168
# Epoch 10/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5949
# Epoch 11/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5790
# Epoch 12/1000
# ...

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Digital_sprout_2023-20240217T004753Z-001/Digital_sprout_2023/데이터셋/pima-indians-diabetes3.csv')
df.head(5)
# Out:
#    pregnant  plasma  pressure  thickness  insulin   bmi  pedigree  age  \
# 0         6     148        72         35        0  33.6     0.627   50
# 1         1      85        66         29        0  26.6     0.351   31
# 2         8     183        64          0        0  23.3     0.672   32
# 3         1      89        66         23       94  28.1     0.167   21
# 4         0     137        40         35      168  43.1     2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
df['diabetes'].value_counts()
# Out:
# count    768.000000
# mean       0.348958
# std        0.476951
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: diabetes, dtype: float64

# %%
df.describe()
# Out:
#          pregnant      plasma    pressure   thickness     insulin         bmi  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#          pedigree         age    diabetes
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
df.corr()
# Out:
#            pregnant    plasma  pressure  thickness   insulin       bmi  \
# pregnant   1.000000  0.129459  0.141282  -0.081672 -0.073535  0.017683
# plasma     0.129459  1.000000  0.152590   0.057328  0.331357  0.221071
# pressure   0.141282  0.152590  1.000000   0.207371  0.088933  0.281805
# thickness -0.081672  0.057328  0.207371   1.000000  0.436783  0.392573
# insulin   -0.073535  0.331357  0.088933   0.436783  1.000000  0.197859
# bmi        0.017683  0.221071  0.281805   0.392573  0.197859  1.000000
# pedigree  -0.033523  0.137337  0.041265   0.183928  0.185071  0.140647
# age        0.544341  0.263514  0.239528  -0.113970 -0.042163  0.036242
# diabetes   0.221898  0.466581  0.065068   0.074752  0.130548  0.292695
#
#            pedigree       age  diabetes
# pregnant  -0.033523  0.544341  0.221898
# plasma     0.137337  0.263514  0.466581
# pressure   0.041265  0.239528  0.065068
# thickness  0.183928 -0.113970  0.074752
# insulin    0.185071 -0.042163  0.130548
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

colormap = plt.cm.gist_heat
plt.figure(figsize = (12, 12))

sns.heatmap(df.corr(), linewidth = 0.5, vmax = 0.5, cmap = colormap, annot = True)
plt.show()

# %%
plt.hist(x = [df.plasma[df.diabetes == 0], df.plasma[df.diabetes == 1]], bins = 30,
         histtype = 'barstacked', label = ['normal', 'diabetes'])

plt.legend()
plt.show()

# %%
plt.hist(x = [df.bmi[df.diabetes == 0], df.bmi[df.diabetes == 1]], bins = 30,
         histtype = 'barstacked', label = ['normal', 'diabetes'])

plt.legend()
plt.show()

# %%
X = df.iloc[:, 0:8]
y = df.iloc[:, 8]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Digital_sprout_2023-20240217T004753Z-001/Digital_sprout_2023/데이터셋/pima-indians-diabetes3.csv')
X = df.iloc[:, 0:8]
y = df.iloc[:, 8]

model = Sequential()
model.add(Dense(12, input_dim = 8, activation = 'relu', name = 'Dense_1'))
model.add(Dense(8, activation = 'relu', name = 'Dense_2'))
model.add(Dense(1, activation = 'sigmoid', name = 'Dense_3'))
model.summary()

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.fit(X, y, epochs = 100, batch_size = 10)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Dense_1 (Dense)             (None, 12)                108
#
#  Dense_2 (Dense)             (None, 8)                 104
#
#  Dense_3 (Dense)             (None, 1)                 9
#
# ...
# Total params: 221 (884.00 Byte)
# Trainable params: 221 (884.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 77/77 [==============================] - 1s 2ms/step - loss: 2.6596 - accuracy: 0.4076
# Epoch 2/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.8137 - accuracy: 0.5208
# Epoch 3/100
# 77/77 [==============================] - 0s 3ms/step - loss: 0.7377 - accuracy: 0.5977
# Epoch 4/100
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7106 - accuracy: 0.6146
# Epoch 5/100
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Digital_sprout_2023-20240217T004753Z-001/Digital_sprout_2023/데이터셋/iris3.csv')

sns.pairplot(df, hue = 'species')
plt.show()

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Digital_sprout_2023-20240217T004753Z-001/Digital_sprout_2023/데이터셋/iris3.csv')

X = df.iloc[:, 0:4]
y = df.iloc[:, 4]
y = pd.get_dummies(y)

model = Sequential()
model.add(Dense(12, input_dim = 4, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(3, activation = 'softmax'))
model.summary()

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
model.fit(X, y, epochs = 100, batch_size = 10)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 12)                60
#
#  dense_1 (Dense)             (None, 8)                 104
#
#  dense_2 (Dense)             (None, 3)                 27
#
# ...
# Total params: 191 (764.00 Byte)
# Trainable params: 191 (764.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 15/15 [==============================] - 2s 16ms/step - loss: 3.4238 - accuracy: 0.3333
# Epoch 2/100
# 15/15 [==============================] - 0s 17ms/step - loss: 2.8882 - accuracy: 0.3333
# Epoch 3/100
# 15/15 [==============================] - 0s 18ms/step - loss: 2.4268 - accuracy: 0.3333
# Epoch 4/100
# 15/15 [==============================] - 0s 19ms/step - loss: 2.0780 - accuracy: 0.3333
# Epoch 5/100
# ...

# %%
import pandas as pd
from google.colab import drive
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Digital_sprout_2023-20240217T004753Z-001/Digital_sprout_2023/데이터셋/sonar3.csv', header = None)
X = df.iloc[:, 0:60]
y = df.iloc[:, 60]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)
model = Sequential()
model.add(Dense(24, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=200, batch_size=10) # verbose = 1
score = model.evaluate(X_test, y_test)
print('Test score:', score[1])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 24)                1464
#
#  dense_16 (Dense)            (None, 10)                250
#
#  dense_17 (Dense)            (None, 1)                 11
#
# ...
# Total params: 1725 (6.74 KB)
# Trainable params: 1725 (6.74 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/200
# 15/15 [==============================] - 1s 2ms/step - loss: 0.6854 - accuracy: 0.5103
# Epoch 2/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6684 - accuracy: 0.6276
# Epoch 3/200
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6540 - accuracy: 0.6690
# Epoch 4/200
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Digital_sprout_2023-20240217T004753Z-001/Digital_sprout_2023/데이터셋/wine.csv', header = None)

X = df.iloc[:, 0:12]
y = df.iloc[:, 12]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = True)

model = Sequential()
model.add(Dense(30, input_dim = 12, activation = 'relu'))
model.add(Dense(12, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
model.summary()

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
history = model.fit(X_train, y_train, epochs = 50, batch_size = 500, validation_split = 0.25)

score = model.evaluate(X_test, y_test)
print('Test loss :', score[0], 'Test accuracy :', score[1])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_18 (Dense)            (None, 30)                390
#
#  dense_19 (Dense)            (None, 12)                372
#
#  dense_20 (Dense)            (None, 8)                 104
#
#  dense_21 (Dense)            (None, 1)                 9
#
# ...
# Total params: 875 (3.42 KB)
# Trainable params: 875 (3.42 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 8/8 [==============================] - 4s 122ms/step - loss: 5.0877 - accuracy: 0.2453 - val_loss: 3.8110 - val_accuracy: 0.2454
# Epoch 2/50
# 8/8 [==============================] - 0s 24ms/step - loss: 3.1743 - accuracy: 0.2497 - val_loss: 2.2171 - val_accuracy: 0.2592
# Epoch 3/50
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Digital_sprout_2023-20240217T004753Z-001/Digital_sprout_2023/데이터셋/wine.csv', header = None)

X = df.iloc[:, 0:12]
y = df.iloc[:, 12]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = True)

model = Sequential()
model.add(Dense(30, input_dim = 12, activation = 'relu'))
model.add(Dense(12, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
model.summary()

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
modelpath = '/content/drive/MyDrive/Colab Notebooks/data (1)/model/wine/{epoch:20}-{val_accuracy:.4f}.hdf5'
checkpointer = ModelCheckpoint(filepath = modelpath, verbose = 1)
history = model.fit(X_train, y_train, epochs = 50, batch_size = 500, validation_split = 0.25, verbose = 0, callbacks = [checkpointer])

score = model.evaluate(X_test, y_test)
print('Test loss :', score[0], 'Test accuracy :', score[1])
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_22 (Dense)            (None, 30)                390
#
#  dense_23 (Dense)            (None, 12)                372
#
#  dense_24 (Dense)            (None, 8)                 104
#
#  dense_25 (Dense)            (None, 1)                 9
#
# ...
# Total params: 875 (3.42 KB)
# Trainable params: 875 (3.42 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
# Epoch 1: saving model to /content/drive/MyDrive/Colab Notebooks/data (1)/model/wine/                   1-0.7646.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Digital_sprout_2023-20240217T004753Z-001/Digital_sprout_2023/데이터셋/wine.csv', header = None)

X = df.iloc[:, 0:12]
y = df.iloc[:, 12]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = True)

model = Sequential()
model.add(Dense(30, input_dim = 12, activation = 'relu'))
model.add(Dense(12, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
model.summary()

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
#modelpath = '/content/drive/MyDrive/Colab Notebooks/data (1)/model/wine/{epoch:20}-{val_accuracy:.4f}.hdf5'
#checkpointer = ModelCheckpoint(filepath = modelpath, verbose = 1)
history = model.fit(X_train, y_train, epochs = 2000, batch_size = 500, validation_split = 0.25, verbose = 1)

score = model.evaluate(X_test, y_test)
print('Test loss :', score[0], 'Test accuracy :', score[1])
hist_df = pd.DataFrame(history.history)

y_val_loss = hist_df['val_loss']
y_train_loss = hist_df['loss']

x_len = np.arange(len(y_train_loss))
plt.plot(x_len, y_val_loss, 'o', c= 'red', markersize = 2, label = 'Validation loss')
plt.plot(x_len, y_train_loss, 'o', c= 'blue', markersize = 2, label = 'Train loss')

plt.legend(loc = 'upper right')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.ylim([0.01, 0.17])
plt.show()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_38 (Dense)            (None, 30)                390
#
#  dense_39 (Dense)            (None, 12)                372
#
#  dense_40 (Dense)            (None, 8)                 104
#
#  dense_41 (Dense)            (None, 1)                 9
#
# ...
# Total params: 875 (3.42 KB)
# Trainable params: 875 (3.42 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2000
# 8/8 [==============================] - 2s 49ms/step - loss: 1.3862 - accuracy: 0.7547 - val_loss: 0.8158 - val_accuracy: 0.7569
# Epoch 2/2000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5547 - accuracy: 0.7952 - val_loss: 0.4972 - val_accuracy: 0.7992
# Epoch 3/2000
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Digital_sprout_2023-20240217T004753Z-001/Digital_sprout_2023/데이터셋/wine.csv', header = None)

X = df.iloc[:, 0:12]
y = df.iloc[:, 12]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = True)

model = Sequential()
model.add(Dense(30, input_dim = 12, activation = 'relu'))
model.add(Dense(12, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
model.summary()

model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 20)
modelpath = '/content/drive/MyDrive/Colab Notebooks/data (1)/model/wine/chapter14_best_model.hdf5'
checkpointer = ModelCheckpoint(filepath = modelpath, monitor = 'val_loss', verbose = 0, save_best_only = True)
history = model.fit(X_train, y_train, epochs = 2000, batch_size = 500, validation_split = 0.25, verbose = 1,
                    callbacks = [early_stopping_callback, checkpointer])

score = model.evaluate(X_test, y_test)
print('Test loss :', score[0], 'Test accuracy :', score[1])
hist_df = pd.DataFrame(history.history)

y_val_loss = hist_df['val_loss']
y_train_loss = hist_df['loss']

x_len = np.arange(len(y_train_loss))
plt.plot(x_len, y_val_loss, 'o', c= 'red', markersize = 2, label = 'Validation loss')
plt.plot(x_len, y_train_loss, 'o', c= 'blue', markersize = 2, label = 'Train loss')

plt.legend(loc = 'upper right')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.ylim([0.01, 0.17])
plt.show()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_42 (Dense)            (None, 30)                390
#
#  dense_43 (Dense)            (None, 12)                372
#
#  dense_44 (Dense)            (None, 8)                 104
#
#  dense_45 (Dense)            (None, 1)                 9
#
# ...
# Total params: 875 (3.42 KB)
# Trainable params: 875 (3.42 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2000
# 8/8 [==============================] - 2s 89ms/step - loss: 0.9043 - accuracy: 0.7637 - val_loss: 0.4350 - val_accuracy: 0.7977
# Epoch 2/2000
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3520 - accuracy: 0.8573 - val_loss: 0.2671 - val_accuracy: 0.9215
# Epoch 3/2000
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Digital_sprout_2023-20240217T004753Z-001/Digital_sprout_2023/데이터셋/house_train.csv')
df.isna().sum().sort_values(ascending = False).head(15)
df = pd.get_dummies(df)
df = df.fillna(df.mean())

df_corr = df.corr()
df_corr_sort = df_corr.sort_values('SalePrice', ascending = False)
df_corr_sort['SalePrice'].head(10)

cols = ['SalePrice', 'OverallQual', 'GarageCars', 'GarageArea', 'TotalBsmtSF']
sns.pairplot(data = df, vars = cols, hue = 'SalePrice', palette = 'husl')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/Digital_sprout_2023-20240217T004753Z-001/Digital_sprout_2023/데이터셋/house_train.csv')
#df.isna().sum().sort_values(ascending = False).head(15)
df = pd.get_dummies(df)
df = df.fillna(df.mean())

df_corr = df.corr()
df_corr_sort = df_corr.sort_values('SalePrice', ascending = False)
df_corr_sort['SalePrice'].head(10)

cols_train = ['OverallQual', 'GarageCars', 'GarageArea', 'TotalBsmtSF']
X_train_pre = df[cols_train]
y = df['SalePrice'].values
X_train, X_test, y_train, y_test = train_test_split(X_train_pre, y, test_size = 0.2)
model = Sequential()
model.add(Dense(10, input_dim = 4, activation = 'relu'))
model.add(Dense(30, activation = 'relu'))
model.add(Dense(40, activation = 'relu'))
model.add(Dense(1))
model.summary()
model.compile(loss = 'mean_squared_error', optimizer = 'adam', metrics = ['mse'])
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 20)
modelpath = './drive/MyDrive/Colab Notebooks/data/model/wine/chapter15_best_model.hdf5'
checkpointer = ModelCheckpoint(filepath = modelpath, monitor = 'val_loss', verbose = 0,
ave_best_only = True)
#train : validation : test = 6:2:2
history = model.fit(X_train, y_train, epochs = 2000, batch_size = 32, validation_split = 0.25, verbose = 1, callbacks = [early_stopping_callback, checkpointer])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 30)                330
#
#  dense_2 (Dense)             (None, 40)                1240
#
#  dense_3 (Dense)             (None, 1)                 41
#
# ...
# Total params: 1661 (6.49 KB)
# Trainable params: 1661 (6.49 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2000
# 28/28 [==============================] - 2s 21ms/step - loss: 39684055040.0000 - mse: 39684055040.0000 - val_loss: 36555272192.0000 - val_mse: 36555272192.0000
# Epoch 2/2000
# 27/28 [===========================>..] - ETA: 0s - loss: 39604805632.0000 - mse: 39604805632.0000
# ...
